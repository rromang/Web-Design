# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = r'Resources/cities.csv'

# %%
weather_df = pd.read_csv(path)

# %%
import datetime
weather_df['Date']=pd.to_datetime(weather_df['Date'],unit='s')
weather_df['Date'] = weather_df['Date'].dt.strftime('%d-%m-%Y %I:%M:%S')

# %%
weather_df.head(15)
# Out:
#     City_ID                City  Cloudiness Country                 Date  \
# 0         0        jacareacanga           0      BR  13-06-2018 03:00:00
# 1         1          kaitangata         100      NZ  13-06-2018 03:55:04
# 2         2            goulburn          20      AU  13-06-2018 03:51:18
# 3         3                lata          76      IN  13-06-2018 03:55:05
# 4         4          chokurdakh           0      RU  13-06-2018 03:55:06
# 5         5            martyush          92      RU  13-06-2018 03:55:06
# 6         6              hobart          20      AU  13-06-2018 03:00:00
# 7         7         broken hill           0      AU  13-06-2018 03:55:11
# 8         8           harnosand           0      SE  13-06-2018 03:20:00
# 9         9           tuatapere           0      NZ  13-06-2018 03:55:12
# 10       10        puerto ayora          90      EC  13-06-2018 03:00:00
# 11       11  havre-saint-pierre          75      CA  13-06-2018 03:00:00
# ...

# %%
weather_df.to_csv(r'Resources/cities_dateconv.csv', index = False)

# %%
sns.set_theme('notebook')

g = sns.relplot(x="Lat", y="Max Temp", hue="Max Temp", data=weather_df)
g.fig.suptitle("vs Max Temperature", y=1.08, size=20)
plt.xlabel("Latitude", size=16)
plt.ylabel("Max Temperature (ºF)", size=16)
plt.title("City Latitude vs Max Temperature (06/13/2018)", size=16)

plt.savefig("max_temp.png", dpi=150, bbox_inches='tight')

# %%
sns.set_theme('notebook')

g = sns.relplot(x="Lat", y="Humidity", hue="Humidity", data=weather_df)
g.fig.suptitle("vs Humidity", y=1.08, size=20)
plt.xlabel("Latitude", size=16)
plt.ylabel("Humidity (%)", size=16)
plt.title("City Latitude vs Humidity (06/13/2018)", size=16)
plt.savefig("humidity.png", dpi=150, bbox_inches='tight')

# %%
sns.set_theme('notebook')

g = sns.relplot(x="Lat", y="Wind Speed", hue="Wind Speed", data=weather_df)
g.fig.suptitle("vs Wind Speed", y=1.08, size=20)
plt.xlabel("Latitude", size=16)
plt.ylabel("Wind Speed (mph)", size=16)
plt.title("City Latitude vs Wind Speed (06/13/2018)", size=16)
plt.savefig("wind_speed.png", dpi=150, bbox_inches='tight')

# %%
sns.set_theme('notebook')

g = sns.relplot(x="Lat", y="Cloudiness", hue="Cloudiness", data=weather_df)
g.fig.suptitle("vs Cloudiness", y=1.08, size=20)
plt.xlabel("Latitude", size=16)
plt.ylabel("Cloudiness (%)", size=16)
plt.title("City Latitude vs Cloudiness (06/13/2018)", size=16)
plt.savefig("cloudiness.png", dpi=150, bbox_inches='tight')
